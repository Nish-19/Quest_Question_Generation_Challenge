# %%
import random
import pandas as pd
from collections import Counter
from sklearn.utils import shuffle

random.seed(37)

# %%
# Import data
train_df = pd.read_csv('../../train_val_split_csv/train.csv')
codex_attr_df = pd.read_csv('codex_augment_attr.csv')
print('Codex Attr Df Head')
codex_attr_df.head()
# Out:
# Codex Attr Df Head
#             pair_id           attribute1 source_title cor_section  \
# 0  23ce8aec4b32591b  causal relationship  king-kojata           5
# 1  23ce8aec4b32591b              setting  king-kojata           5
# 2  23ce8aec4b32591b               action  king-kojata           5
# 3  23ce8aec4b32591b   outcome resolution  king-kojata           5
# 4  23ce8aec4b32591b   outcome resolution  king-kojata           5
#
#                                           answer  \
# 0                            To go on a journey.
# 1                                 on his journey
# 2                   thirty little white garments
# 3                              They disappeared.
# 4  He will not be able to find the magic castle.
#
#                                               prompt  \
# 0  Generate attriburte from story, answer and que...
# 1  Generate attriburte from story, answer and que...
# 2  Generate attriburte from story, answer and que...
# 3  Generate attriburte from story, answer and que...
# 4  Generate attriburte from story, answer and que...
#
#                                             question  \
# 0                      Why did Milan leave his home?
# 1  Where did Milan see a lake as smooth as glass ...
# 2          What did Milan notice lying on the grass?
# 3  What happened when the ducks turned into maidens?
# 4  What will happen if Milan does not find the th...
#
#                      predicted attribute
# 0  The attribute is: causal relationship
# 1              The attribute is: setting
# 2               The attribute is: action
# 3   The attribute is: outcome resolution
# 4           The attribute is: prediction

# %%
def preprocess_codex_df(codex_df):
    '''
    1. Extract attribute name from predicted attribute
    2. Change column names -> attribute1-org_attr and predicted attribute - attribute1
    '''
    prefix = 'The attribute is: '
    attrs = codex_df['predicted attribute'].apply(lambda strmine: strmine.split(prefix)[1])
    codex_df.drop(columns=['predicted attribute'], inplace=True)
    codex_df.rename(columns={'attribute1':'codex_attribute'})
    codex_df['attribute1'] = attrs

# %%
preprocess_codex_df(codex_attr_df) # Inplace changes
codex_attr_df.head()
# Out:
#             pair_id           attribute1 source_title cor_section  \
# 0  23ce8aec4b32591b  causal relationship  king-kojata           5
# 1  23ce8aec4b32591b              setting  king-kojata           5
# 2  23ce8aec4b32591b               action  king-kojata           5
# 3  23ce8aec4b32591b   outcome resolution  king-kojata           5
# 4  23ce8aec4b32591b           prediction  king-kojata           5
#
#                                           answer  \
# 0                            To go on a journey.
# 1                                 on his journey
# 2                   thirty little white garments
# 3                              They disappeared.
# 4  He will not be able to find the magic castle.
#
#                                               prompt  \
# 0  Generate attriburte from story, answer and que...
# 1  Generate attriburte from story, answer and que...
# 2  Generate attriburte from story, answer and que...
# 3  Generate attriburte from story, answer and que...
# 4  Generate attriburte from story, answer and que...
#
#                                             question
# 0                      Why did Milan leave his home?
# 1  Where did Milan see a lake as smooth as glass ...
# 2          What did Milan notice lying on the grass?
# 3  What happened when the ducks turned into maidens?
# 4  What will happen if Milan does not find the th...

# %%
def get_attr_stats(train_df, codex_df, save_name):
    print('Original Trainset size', len(train_df))
    print('Augmented Trainset size', len(codex_df))
    org_count = dict(sorted(dict(Counter(train_df['attribute1'])).items()))
    codex_count = dict(sorted(dict(Counter(codex_df['attribute1'])).items()))
    attr_list = list(org_count.keys())
    org_attr_count = list(org_count.values())
    codex_attr_count = list(codex_count.values())
    total_attr_count = [org+codex for org, codex in zip(org_attr_count, codex_attr_count)]
    org_attr_sum, codex_attr_sum = sum(org_attr_count), sum(codex_attr_count)
    org_attr_per = [ctr/org_attr_sum for ctr in org_attr_count]
    codex_attr_per = [ctr/codex_attr_sum for ctr in codex_attr_count]
    attr_comp_df = pd.DataFrame()
    attr_comp_df['Attribute'] = attr_list
    attr_comp_df['Original Count'] = org_attr_count
    attr_comp_df['Codex Count'] = codex_attr_count
    attr_comp_df['Total Count'] = total_attr_count
    attr_comp_df['Original Percent'] = org_attr_per
    attr_comp_df['Codex Percent'] = codex_attr_per
    if save_name is not None:
        attr_comp_df.to_csv(save_name, index=False)
    return attr_comp_df

# %%
attr_comp_df = get_attr_stats(train_df, codex_attr_df, 'org_and_codex_attr_stats.csv')
attr_comp_df
# Out:
# Original Trainset size 6005
# Augmented Trainset size 91433
#              Attribute  Original Count  Codex Count  Total Count  \
# 0               action            1921        31352        33273
# 1  causal relationship            1673        27893        29566
# 2            character             666         7497         8163
# 3              feeling             574         4923         5497
# 4   outcome resolution             594         4894         5488
# 5           prediction             225         5221         5446
# 6              setting             352         9653        10005
#
#    Original Percent  Codex Percent
# 0          0.319900       0.342896
# 1          0.278601       0.305065
# 2          0.110908       0.081994
# 3          0.095587       0.053843
# 4          0.098918       0.053526
# 5          0.037469       0.057102
# 6          0.058618       0.105575

# %%
# NOTE: Balanced Augment (Upto least total-count)
min_tot_count = min(attr_comp_df['Total Count'])
min_index = attr_comp_df['Total Count'].tolist().index(min_tot_count)
min_attr_name = attr_comp_df.loc[min_index, 'Attribute']
print('Minimum Attribute "%s": %d'%(min_attr_name, min_tot_count))

# Shuffle codex data
allowed_count_lst = [min_tot_count-org for org in attr_comp_df['Original Count']] 
allowed_count_dict = {atr_name:allowed_count for atr_name, allowed_count in zip(attr_comp_df['Attribute'].tolist(), allowed_count_lst)}
print(allowed_count_dict)

# # Start appending
# for i, row in codex_attr_df.iterrows():
#     print(i, row)
all_rows = []
for i in range(len(codex_attr_df)):
    row_vals = codex_attr_df.loc[i].values.tolist()
    all_rows.append(row_vals)
# Shuffle all_rows
random.shuffle(all_rows)
    
append_rows = []
for row_list in all_rows:
    if allowed_count_dict[row_list[1]] > 0:
        append_rows.append(row_list)
        allowed_count_dict[row_list[1]] -= 1

assert len(append_rows) == sum(allowed_count_lst)
print(len(append_rows))

append_df = pd.DataFrame(append_rows, columns=codex_attr_df.columns)

# Augment Dataset
codex_aug_train_df = train_df.append(pd.DataFrame(append_df,
                            columns=train_df.columns),
                            ignore_index=True)
codex_aug_train_df
# Out:
# Minimum Attribute "prediction": 5446
# {'action': 3525, 'causal relationship': 3773, 'character': 4780, 'feeling': 4872, 'outcome resolution': 4852, 'prediction': 5221, 'setting': 5094}
# 32117
# /var/folders/6q/gxv2z40x4jj37_ksv541z0m40000gn/T/ipykernel_12720/3888324222.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   codex_aug_train_df = train_df.append(pd.DataFrame(append_df,
#                 pair_id               source_title cor_section  \
# 0      23ce8aec4b32591b                king-kojata           5
# 1      f3cfe23c09215e97                black-sheep           5
# 2      7de1192ea017582b   the-boyhood-of-cuchulain           2
# 3      606c0713383559a6             the-toad-woman         8,9
# 4      6a9173711794569b     sheem-the-forsaken-boy          24
# ...                 ...                        ...         ...
# 38117  6010b699fa525cc7                       flax           8
# 38118  b8acaf6247ba5748  sagacious-monkey-and-boar           2
# 38119  a25d08011f3d55c8    the-enchanted-moccasins          18
# 38120  c6bb382ee8c9560d               the-red-swan          25
# 38121  7527bfebf88a5328                kings-hares           8
#
#                                                   answer  \
# 0                                                a horse
# 1                                                comical
# 2                                                alarmed
# 3                                             astonished
# 4                                  strove to catch Sheem
# ...                                                  ...
# 38117  It will be worn out before it had half finishe...
# 38118  He will be killed then roasted, stewed, and ea...
# 38119                            He would be taken home.
# 38120                           He will be sent to jail.
# 38121                 cut three red strips from his back
#
#                                                 question local_or_sum  \
# 0       What did the Prince tell his father to give him?        local
# 1      How did the ram look without fur and because h...        local
# 2      How did Dectera secretly feel about Setanta's ...        local
# 3      How did the Toad-Woman feel when she saw her c...      summary
# 4                  What did Owasso do when he saw Sheem?        local
# ...                                                  ...          ...
# 38117           What will the paper do with its journey?          NaN
# 38118                    What will happen to the monkey?          NaN
# 38119  What will happen when Ko-ko put on the enchant...          NaN
# 38120  What will happen to the foolish fellow if he k...          NaN
# 38121       What will the king do if Esben loses a hare?          NaN
#
#        attribute1 attribute2  ex_or_im
# 0          action        NaN  explicit
# 1       character        NaN  explicit
# 2         feeling        NaN  explicit
# 3         feeling        NaN  explicit
# 4          action        NaN  explicit
# ...           ...        ...       ...
# 38117  prediction        NaN       NaN
# 38118  prediction        NaN       NaN
# 38119  prediction        NaN       NaN
# 38120  prediction        NaN       NaN
# 38121  prediction        NaN       NaN
#
# [38122 rows x 9 columns]

# %%
new_attr_df = get_attr_stats(train_df, codex_aug_train_df, None)
new_attr_df
# Out:
# Original Trainset size 6005
# Augmented Trainset size 38122
#              Attribute  Original Count  Codex Count  Total Count  \
# 0               action            1921         5446         7367
# 1  causal relationship            1673         5446         7119
# 2            character             666         5446         6112
# 3              feeling             574         5446         6020
# 4   outcome resolution             594         5446         6040
# 5           prediction             225         5446         5671
# 6              setting             352         5446         5798
#
#    Original Percent  Codex Percent
# 0          0.319900       0.142857
# 1          0.278601       0.142857
# 2          0.110908       0.142857
# 3          0.095587       0.142857
# 4          0.098918       0.142857
# 5          0.037469       0.142857
# 6          0.058618       0.142857

# %%
codex_aug_train_df.to_csv('codex_attr_balanced_augment.csv', index=False)

# %% [markdown]
# # Balanced Codex Only + Balanced (Exact Match Augment)

# %%
# NOTE: Balanced Augment - 2 (Upto least codex-count)
min_aug_count = min(attr_comp_df['Codex Count'])
min_index = attr_comp_df['Codex Count'].tolist().index(min_aug_count)
min_attr_name = attr_comp_df.loc[min_index, 'Attribute']
print('Minimum Attribute "%s": %d'%(min_attr_name, min_aug_count))

# Shuffle codex data
allowed_count_dict = {atr_name:min_aug_count for atr_name in attr_comp_df['Attribute'].tolist()}
print(allowed_count_dict)

# # Start appending
# for i, row in codex_attr_df.iterrows():
#     print(i, row)
all_rows = []
for i in range(len(codex_attr_df)):
    row_vals = codex_attr_df.loc[i].values.tolist()
    all_rows.append(row_vals)
# Shuffle all_rows
random.shuffle(all_rows)
    
append_rows = []
for row_list in all_rows:
    if allowed_count_dict[row_list[1]] > 0:
        append_rows.append(row_list)
        allowed_count_dict[row_list[1]] -= 1

print(len(append_rows))

append_df_2 = pd.DataFrame(append_rows, columns=codex_attr_df.columns)

# # Augment Dataset
# codex_aug_train_df_2 = train_df.append(pd.DataFrame(append_df_2,
#                             columns=train_df.columns),
#                             ignore_index=True)
# codex_aug_train_df_2
# Out:
# Minimum Attribute "outcome resolution": 4894
# {'action': 4894, 'causal relationship': 4894, 'character': 4894, 'feeling': 4894, 'outcome resolution': 4894, 'prediction': 4894, 'setting': 4894}
# 34258

# %%
# Load Sel Match Data
sel_ex_match_df = pd.read_csv('../Sel_Exact_Match_Augment_Train.csv')
sel_ex_match_df
# Out:
#                 pair_id              source_title cor_section  \
# 0      23ce8aec4b32591b               king-kojata           5
# 1      f3cfe23c09215e97               black-sheep           5
# 2      7de1192ea017582b  the-boyhood-of-cuchulain           2
# 3      606c0713383559a6            the-toad-woman         8,9
# 4      6a9173711794569b    sheem-the-forsaken-boy          24
# ...                 ...                       ...         ...
# 12574  04aa82f8be4d53dc       the-dragon-princess      11, 12
# 12575  91f18b64e3745d3b   the-enchanted-moccasins           8
# 12576  f4847f15729e5a29          murmur-goose-egg       19,27
# 12577  7f934010c2f55e6f             the-white-cat          48
# 12578  75e085264d6f5cce    story-of-princess-hase          18
#
#                       answer  \
# 0                    a horse
# 1                    comical
# 2                    alarmed
# 3                 astonished
# 4      strove to catch Sheem
# ...                      ...
# 12574                pleased
# 12575                  angry
# 12576              the devil
# 12577   joy and astonishment
# 12578              Hase-Hime
#
#                                                 question local_or_sum  \
# 0       What did the Prince tell his father to give him?        local
# 1      How did the ram look without fur and because h...        local
# 2      How did Dectera secretly feel about Setanta's ...        local
# 3      How did the Toad-Woman feel when she saw her c...      summary
# 4                  What did Owasso do when he saw Sheem?        local
# ...                                                  ...          ...
# 12574     How did the emperor feel when he saw the gems?      summary
# 12575  How did the younger brother feel after he came...        local
# 12576                                   Who beat Murmur?      summary
# 12577  How did the King and his courtiers feel after ...        local
# 12578                  Who was everyone gossiping about?        local
#
#        attribute1 attribute2  ex_or_im
# 0          action        NaN  explicit
# 1       character        NaN  explicit
# 2         feeling        NaN  explicit
# 3         feeling        NaN  explicit
# 4          action        NaN  explicit
# ...           ...        ...       ...
# 12574  prediction    feeling  explicit
# 12575  prediction    feeling  implicit
# 12576  prediction  character  explicit
# 12577  prediction     action  explicit
# 12578  prediction  character  explicit
#
# [12579 rows x 9 columns]

# %%
# Append SEL Ex Match with codex data
sel_ex_match_df['aug_type'] = ['org' for _ in range(len(sel_ex_match_df))]
append_df_2['aug_type'] = ['codex' for _ in range(len(append_df_2))]
codex_aug_train_df_2 = sel_ex_match_df.append(pd.DataFrame(append_df_2,
                            columns=sel_ex_match_df.columns),
                            ignore_index=True)
# Out:
# /var/folders/6q/gxv2z40x4jj37_ksv541z0m40000gn/T/ipykernel_12720/1985907956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   codex_aug_train_df_2 = sel_ex_match_df.append(pd.DataFrame(append_df_2,

# %%
new_attr_df_2 = get_attr_stats(train_df, codex_aug_train_df_2, None)
new_attr_df_2
# Out:
# Original Trainset size 6005
# Augmented Trainset size 46837
#              Attribute  Original Count  Codex Count  Total Count  \
# 0               action            1921         6815         8736
# 1  causal relationship            1673         6567         8240
# 2            character             666         6691         7357
# 3              feeling             574         6691         7265
# 4   outcome resolution             594         6691         7285
# 5           prediction             225         6691         6916
# 6              setting             352         6691         7043
#
#    Original Percent  Codex Percent
# 0          0.319900       0.145505
# 1          0.278601       0.140210
# 2          0.110908       0.142857
# 3          0.095587       0.142857
# 4          0.098918       0.142857
# 5          0.037469       0.142857
# 6          0.058618       0.142857

# %%
codex_aug_train_df_2.to_csv('codexattremmatch_augment.csv', index=False)
